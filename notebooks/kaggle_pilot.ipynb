# %% [markdown]
# # Transcribe pilot on Kaggle
#
# 1. **Add data:** your private dataset with the audio files and their DOCX transcripts (matching names).
# 2. **Settings:** Accelerator = GPU T4 x2 (or P100), Internet = On.
# 3. **Save Version > Save & Run All (Commit)**, then close the tab. It runs in the background.
# 4. When the version finishes, open it > **Output** > download `pilot_reports.zip`.
#
# Optional settings go before `bash`, e.g. `MODELS=small LANGS=sw bash scripts/kaggle_pilot.sh`.

# %%
# !rm -rf transcribe && git clone -q --depth 1 -b matt/relaxed-meitner-2lfrx6 https://github.com/mattobryan/transcribe.git
# !cd transcribe && bash scripts/kaggle_pilot.sh
